# %% [markdown]
# #Experiment 1

# %%
# ===============================================
# 0. Imports
# ===============================================
import os
import zipfile
from glob import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import KFold
import tensorflow.keras.backend as K
from sklearn.utils import shuffle
import albumentations as A

# ✅ Enable mixed precision
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")

# ===============================================
# 1. Unzip Dataset + Auto Path Fix
# ===============================================
zip_path = "/content/stage1_train.zip"
extract_root = "/content/stage1_train"
os.makedirs(extract_root, exist_ok=True)

if not any(os.path.isdir(os.path.join(extract_root, d)) for d in os.listdir(extract_root)):
    print("📦 Extracting dataset...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_root)
    print("✅ Extraction completed.")
else:
    print("✅ Dataset already extracted.")

candidates = [d for d in glob(os.path.join(extract_root, "*")) if os.path.isdir(d)]
extract_path = candidates[0] if len(candidates) == 1 else extract_root
print("✅ Using dataset folder:", extract_path)
print("🔍 First 5 contents:", os.listdir(extract_path)[:5])

# ===============================================
# 2. Load Data Function (Recursive)
# ===============================================
def load_data(data_dir, img_size=(512, 512)):
    images, masks = [], []
    all_ids = [d for d in glob(os.path.join(data_dir, "*")) if os.path.isdir(d)]
    print(f"🔍 Found {len(all_ids)} patient folders")

    for img_id in tqdm(all_ids, desc="Loading patients"):
        img_path_list = glob(os.path.join(img_id, "images", "*.png"))
        mask_paths = glob(os.path.join(img_id, "masks", "*.png"))

        if len(img_path_list) == 0 or len(mask_paths) == 0:
            continue

        image = cv2.imread(img_path_list[0], cv2.IMREAD_COLOR)
        if image is None:
            continue
        image = cv2.resize(image, img_size)
        image = image / 255.0

        mask = np.zeros(img_size, dtype=np.uint8)
        for mp in mask_paths:
            m = cv2.imread(mp, cv2.IMREAD_GRAYSCALE)
            if m is None:
                continue
            m = cv2.resize(m, img_size)
            mask = np.maximum(mask, m)
        mask = (mask > 127).astype(np.float32)
        mask = np.expand_dims(mask, axis=-1)

        images.append(image)
        masks.append(mask)

    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.float32)

# ===============================================
# 3. Load Dataset
# ===============================================
IMG_SIZE = (512, 512)
images, masks = load_data(extract_path, img_size=IMG_SIZE)
print("✅ Images:", images.shape)
print("✅ Masks:", masks.shape)

idx = np.random.randint(0, len(images))
plt.subplot(1, 2, 1); plt.imshow(images[idx]); plt.title("Image"); plt.axis("off")
plt.subplot(1, 2, 2); plt.imshow(masks[idx].squeeze(), cmap="gray"); plt.title("Mask"); plt.axis("off")
plt.show()

# ===============================================
# 4. Loss Functions
# ===============================================
def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 1 - (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    return bce + dice

# ===============================================
# 5. TransUNet Model
# ===============================================
class PatchEmbedding(layers.Layer):
    def __init__(self, embed_dim=192):
        super().__init__()
        self.proj = layers.Conv2D(embed_dim, kernel_size=1, strides=1, padding="valid")
        self.flatten = layers.Reshape((-1, embed_dim))

    def call(self, x):
        x = self.proj(x)
        x = self.flatten(x)
        return x

class PositionalEncoding(layers.Layer):
    def __init__(self, num_patches, embed_dim):
        super().__init__()
        self.pos_embed = self.add_weight(
            name="pos_embed",
            shape=(1, num_patches, embed_dim),
            initializer="random_normal"
        )

    def call(self, x):
        return x + self.pos_embed

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim=192, num_heads=12, mlp_dim=768, dropout=0.1):
        super().__init__()
        self.norm1 = layers.LayerNormalization(epsilon=1e-6)
        self.attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=dropout)
        self.drop1 = layers.Dropout(dropout)
        self.norm2 = layers.LayerNormalization(epsilon=1e-6)
        self.mlp = models.Sequential([
            layers.Dense(mlp_dim, activation=tf.nn.gelu),
            layers.Dropout(dropout),
            layers.Dense(embed_dim),
            layers.Dropout(dropout),
        ])

    def call(self, x):
        attn_output = self.attn(self.norm1(x), self.norm1(x))
        x = x + self.drop1(attn_output)
        mlp_output = self.mlp(self.norm2(x))
        return x + mlp_output

def build_transformer_encoder(x, num_layers=4, embed_dim=192, num_heads=12, mlp_dim=768):
    for _ in range(num_layers):
        x = TransformerBlock(embed_dim, num_heads, mlp_dim)(x)
    return x

def build_transunet(input_shape=(512, 512, 3), num_classes=1):
    inputs = layers.Input(shape=input_shape)

    base_model = tf.keras.applications.ResNet50(
        include_top=False,
        weights="imagenet",
        input_tensor=inputs
    )

    skip1 = base_model.get_layer("conv1_relu").output
    skip2 = base_model.get_layer("conv2_block3_out").output
    skip3 = base_model.get_layer("conv3_block4_out").output
    cnn_feature = base_model.get_layer("conv4_block6_out").output

    patches = PatchEmbedding(embed_dim=192)(cnn_feature)
    num_patches = patches.shape[1]
    patches = PositionalEncoding(num_patches, 192)(patches)
    transformer_out = build_transformer_encoder(patches)

    h, w = cnn_feature.shape[1], cnn_feature.shape[2]
    x = layers.Reshape((h, w, 192))(transformer_out)

    # Decoder
    x = layers.Conv2DTranspose(512, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip3])
    x = layers.Conv2D(512, 3, padding="same", activation=tf.nn.leaky_relu)(x)

    x = layers.Conv2DTranspose(256, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip2])
    x = layers.Conv2D(256, 3, padding="same", activation=tf.nn.leaky_relu)(x)

    x = layers.Conv2DTranspose(128, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip1])
    x = layers.Conv2D(128, 3, padding="same", activation=tf.nn.leaky_relu)(x)

    x = layers.Conv2DTranspose(64, 3, strides=2, padding="same")(x)
    x = layers.Conv2D(64, 3, padding="same", activation=tf.nn.leaky_relu)(x)

    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid", dtype="float32")(x)
    return models.Model(inputs, outputs, name="TransUNet")

# ===============================================
# 6. Metrics Function
# ===============================================
def calculate_metrics(y_true, y_pred, threshold=0.5, smooth=1e-6):
    y_pred_bin = (y_pred > threshold).astype(np.float32)
    pixel_acc = np.mean(y_true == y_pred_bin)
    intersection = np.sum(y_true * y_pred_bin)
    dice = (2 * intersection + smooth) / (np.sum(y_true) + np.sum(y_pred_bin) + smooth)
    union = np.sum(y_true) + np.sum(y_pred_bin) - intersection
    iou = (intersection + smooth) / (union + smooth)
    return pixel_acc, dice, iou

# ===============================================
# 7. K-Fold Cross Validation with Augmentation
# ===============================================
# ✅ Define Albumentations pipeline
train_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, p=0.5),
    A.GridDistortion(p=0.2),
    A.CoarseDropout(max_holes=10, max_height=32, max_width=32, p=0.3),
])

images, masks = shuffle(images, masks, random_state=42)
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
fold_metrics = []
augment_factor = 3  # 🔸you can set 5 or 10 for heavier augmentation

for fold, (train_idx, val_idx) in enumerate(kf.split(images)):
    print(f"\n📂 Fold {fold+1}/{num_folds}")

    X_train, X_val = images[train_idx], images[val_idx]
    y_train, y_val = masks[train_idx], masks[val_idx]

    # ------------------------------------
    # ✅ Augment Training Data
    # ------------------------------------
    aug_X, aug_y = [], []
    print(f"🔄 Augmenting training data ×{augment_factor} ...")
    for img, mask in tqdm(zip(X_train, y_train), total=len(X_train)):
        for _ in range(augment_factor):
            augmented = train_transform(image=(img * 255).astype(np.uint8), mask=(mask * 255).astype(np.uint8))
            img_aug = augmented["image"].astype(np.float32) / 255.0
            mask_aug = (augmented["mask"] > 127).astype(np.float32)

            if img_aug.ndim == 2:
                img_aug = np.expand_dims(img_aug, axis=-1)
            if mask_aug.ndim == 2:
                mask_aug = np.expand_dims(mask_aug, axis=-1)

            img_aug = np.reshape(img_aug, (512, 512, 3))
            mask_aug = np.reshape(mask_aug, (512, 512, 1))

            aug_X.append(img_aug)
            aug_y.append(mask_aug)

    X_train = np.array(aug_X, dtype=np.float32)
    y_train = np.array(aug_y, dtype=np.float32)
    print(f"✅ Augmented training set: {X_train.shape}, {y_train.shape}")

    # ------------------------------------
    # Build & Train Model
    # ------------------------------------
    model = build_transunet(input_shape=(512, 512, 3))
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), loss=bce_dice_loss, metrics=["accuracy"])

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            f"transunet_fold{fold+1}.weights.h5",
            save_best_only=True,
            monitor="val_loss"
        )
    ]

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=16,  # You can try 32 if GPU memory allows
        callbacks=callbacks,
        verbose=1
    )

    # Evaluate
    preds_val = model.predict(X_val)
    pixel_acc, dice_score, iou_score = calculate_metrics(y_val, preds_val)

    print(f"✅ Fold {fold+1} Results:")
    print(f"   Pixel Accuracy: {pixel_acc:.4f}")
    print(f"   Dice Score:     {dice_score:.4f}")
    print(f"   IoU Score:      {iou_score:.4f}")

    fold_metrics.append((pixel_acc, dice_score, iou_score))

# ===============================================
# 8. Average Metrics Across Folds
# ===============================================
fold_metrics = np.array(fold_metrics)
mean_metrics = np.mean(fold_metrics, axis=0)
std_metrics = np.std(fold_metrics, axis=0)

print("\n📊 Final Cross-Validation Results:")
print(f"Pixel Accuracy: {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
print(f"Dice Score:     {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
print(f"IoU Score:      {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")
# Out:
# ✅ Dataset already extracted.
# ✅ Using dataset folder: /content/stage1_train
# 🔍 First 5 contents: ['dd54adb80393de7769b9853c0aa2ee9b240905d0e99c59d4ccd99401f327aa05', 'f0c9f135c62572f3669a75b2c735e4477dc77fac85e653426ee2b3bcfbed7aaf', '5953af5080d981b554529971903d8bee9871457a4361b51f04ba04f43793dd8f', 'f4faa3a409014db1865074c5f66a0255f71ae3faba03265da0b3b91f68e8a8f0', '0e4c2e2780de7ec4312f0efcd86b07c3738d21df30bb4643659962b4da5505a3']
# 🔍 Found 670 patient folders
# Loading patients: 100%|██████████| 670/670 [00:28<00:00, 23.14it/s]
# ✅ Images: (670, 512, 512, 3)
# ✅ Masks: (670, 512, 512, 1)
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /tmp/ipython-input-373331237.py:219: UserWarning: Argument(s) 'max_holes, max_height, max_width' are not valid for transform CoarseDropout
#   A.CoarseDropout(max_holes=10, max_height=32, max_width=32, p=0.3),
# 📂 Fold 1/5
# 🔄 Augmenting training data ×3 ...
# 100%|██████████| 536/536 [00:06<00:00, 79.38it/s]
# ✅ Augmented training set: (1608, 512, 512, 3), (1608, 512, 512, 1)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8970 - loss: 0.6596
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 496s 2s/step - accuracy: 0.8975 - loss: 0.6568 - val_accuracy: 0.8652 - val_loss: 2.7926
# Epoch 2/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 158ms/step - accuracy: 0.9741 - loss: 0.1877 - val_accuracy: 0.8652 - val_loss: 2.8759
# Epoch 3/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9776 - loss: 0.1627
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 17s 170ms/step - accuracy: 0.9776 - loss: 0.1627 - val_accuracy: 0.8652 - val_loss: 2.6733
# Epoch 4/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9791 - loss: 0.1562
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 17s 169ms/step - accuracy: 0.9791 - loss: 0.1562 - val_accuracy: 0.8652 - val_loss: 2.4391
# Epoch 5/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9788 - loss: 0.1546
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 17s 170ms/step - accuracy: 0.9788 - loss: 0.1545 - val_accuracy: 0.8652 - val_loss: 2.2387
# Epoch 6/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9806 - loss: 0.1411
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 17s 169ms/step - accuracy: 0.
50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 157ms/step - accuracy: 0.9915 - loss: 0.0611 - val_accuracy: 0.9798 - val_loss: 0.1638
# Epoch 43/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 157ms/step - accuracy: 0.9915 - loss: 0.0605 - val_accuracy: 0.9796 - val_loss: 0.1658
# Epoch 44/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 157ms/step - accuracy: 0.9918 - loss: 0.0595 - val_accuracy: 0.9792 - val_loss: 0.1716
# Epoch 45/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 157ms/step - accuracy: 0.9920 - loss: 0.0568 - val_accuracy: 0.9799 - val_loss: 0.1652
# Epoch 46/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 157ms/step - accuracy: 0.9917 - loss: 0.0585 - val_accuracy: 0.9797 - val_loss: 0.1677
# Epoch 47/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 156ms/step - accuracy: 0.9924 - loss: 0.0551 - val_accuracy: 0.9793 - val_loss: 0.1697
# Epoch 48/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 157ms/step - accuracy: 0.9923 - loss: 0.0561 - val_accuracy: 0.9792 - val_loss: 0.1758
# Epoch 49/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 156ms/step - accuracy: 0.9924 - loss: 0.0537 - val_accuracy: 0.9797 - val_loss: 0.1732
# Epoch 50/50
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 156ms/step - accuracy: 0.9929 - loss: 0.0516 - val_accuracy: 0.9801 - val_loss: 0.1730
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step
# ✅ Fold 5 Results:
#    Pixel Accuracy: 0.9801
#    Dice Score:     0.9286
#    IoU Score:      0.8666
#
# 📊 Final Cross-Validation Results:
# Pixel Accuracy: 0.9780 ± 0.0019
# Dice Score:     0.9210 ± 0.0081
# IoU Score:      0.8536 ± 0.0138

# %% [markdown]
# #Experiment 2

# %%
# ===============================================
# 0. Imports
# ===============================================
import os, zipfile
from glob import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import KFold
import tensorflow.keras.backend as K
from sklearn.utils import shuffle
import albumentations as A

# ✅ Enable mixed precision
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")

# ===============================================
# 1. Unzip Dataset + Auto Path Fix
# ===============================================
zip_path = "/content/stage1_train.zip"
extract_root = "/content/stage1_train"
os.makedirs(extract_root, exist_ok=True)

if not any(os.path.isdir(os.path.join(extract_root, d)) for d in os.listdir(extract_root)):
    print("📦 Extracting dataset...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_root)
    print("✅ Extraction completed.")
else:
    print("✅ Dataset already extracted.")

candidates = [d for d in glob(os.path.join(extract_root, "*")) if os.path.isdir(d)]
extract_path = candidates[0] if len(candidates) == 1 else extract_root
print("✅ Using dataset folder:", extract_path)
print("🔍 First 5 contents:", os.listdir(extract_path)[:5])

# ===============================================
# 2. Load Data Function
# ===============================================
def load_data(data_dir, img_size=(512, 512)):
    images, masks = [], []
    all_ids = [d for d in glob(os.path.join(data_dir, "*")) if os.path.isdir(d)]
    print(f"🔍 Found {len(all_ids)} patient folders")

    for img_id in tqdm(all_ids, desc="Loading patients"):
        img_path_list = glob(os.path.join(img_id, "images", "*.png"))
        mask_paths = glob(os.path.join(img_id, "masks", "*.png"))
        if len(img_path_list) == 0 or len(mask_paths) == 0:
            continue

        image = cv2.imread(img_path_list[0], cv2.IMREAD_COLOR)
        if image is None:
            continue
        image = cv2.resize(image, img_size)
        image = image / 255.0

        mask = np.zeros(img_size, dtype=np.uint8)
        for mp in mask_paths:
            m = cv2.imread(mp, cv2.IMREAD_GRAYSCALE)
            if m is None:
                continue
            m = cv2.resize(m, img_size)
            mask = np.maximum(mask, m)
        mask = (mask > 127).astype(np.float32)
        mask = np.expand_dims(mask, axis=-1)

        images.append(image)
        masks.append(mask)

    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.float32)

# ===============================================
# 3. Load Dataset
# ===============================================
IMG_SIZE = (512, 512)
images, masks = load_data(extract_path, img_size=IMG_SIZE)
print("✅ Images:", images.shape)
print("✅ Masks:", masks.shape)

# ===============================================
# 4. Loss Functions
# ===============================================
def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 1 - (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    return bce + dice

# ===============================================
# 5. TransUNet Model
# ===============================================
class PatchEmbedding(layers.Layer):
    def __init__(self, embed_dim=192):
        super().__init__()
        self.proj = layers.Conv2D(embed_dim, kernel_size=1, strides=1, padding="valid")
        self.flatten = layers.Reshape((-1, embed_dim))

    def call(self, x):
        x = self.proj(x)
        x = self.flatten(x)
        return x

class PositionalEncoding(layers.Layer):
    def __init__(self, num_patches, embed_dim):
        super().__init__()
        self.pos_embed = self.add_weight(
            name="pos_embed",
            shape=(1, num_patches, embed_dim),
            initializer="random_normal"
        )

    def call(self, x):
        return x + self.pos_embed

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim=192, num_heads=12, mlp_dim=768, dropout=0.1):
        super().__init__()
        self.norm1 = layers.LayerNormalization(epsilon=1e-6)
        self.attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=dropout)
        self.drop1 = layers.Dropout(dropout)
        self.norm2 = layers.LayerNormalization(epsilon=1e-6)
        self.mlp = models.Sequential([
            layers.Dense(mlp_dim, activation=tf.nn.gelu),
            layers.Dropout(dropout),
            layers.Dense(embed_dim),
            layers.Dropout(dropout),
        ])

    def call(self, x):
        attn_output = self.attn(self.norm1(x), self.norm1(x))
        x = x + self.drop1(attn_output)
        mlp_output = self.mlp(self.norm2(x))
        return x + mlp_output

def build_transformer_encoder(x, num_layers=4, embed_dim=192, num_heads=12, mlp_dim=768):
    for _ in range(num_layers):
        x = TransformerBlock(embed_dim, num_heads, mlp_dim)(x)
    return x

def build_transunet(input_shape=(512, 512, 3), num_classes=1):
    inputs = layers.Input(shape=input_shape)
    base_model = tf.keras.applications.ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
    skip1 = base_model.get_layer("conv1_relu").output
    skip2 = base_model.get_layer("conv2_block3_out").output
    skip3 = base_model.get_layer("conv3_block4_out").output
    cnn_feature = base_model.get_layer("conv4_block6_out").output

    patches = PatchEmbedding(embed_dim=192)(cnn_feature)
    num_patches = patches.shape[1]
    patches = PositionalEncoding(num_patches, 192)(patches)
    transformer_out = build_transformer_encoder(patches)

    h, w = cnn_feature.shape[1], cnn_feature.shape[2]
    x = layers.Reshape((h, w, 192))(transformer_out)

    # Decoder
    x = layers.Conv2DTranspose(512, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip3])
    x = layers.Conv2D(512, 3, padding="same", activation=tf.nn.leaky_relu)(x)
    x = layers.Conv2DTranspose(256, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip2])
    x = layers.Conv2D(256, 3, padding="same", activation=tf.nn.leaky_relu)(x)
    x = layers.Conv2DTranspose(128, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip1])
    x = layers.Conv2D(128, 3, padding="same", activation=tf.nn.leaky_relu)(x)
    x = layers.Conv2DTranspose(64, 3, strides=2, padding="same")(x)
    x = layers.Conv2D(64, 3, padding="same", activation=tf.nn.leaky_relu)(x)
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid", dtype="float32")(x)
    return models.Model(inputs, outputs, name="TransUNet")

# ===============================================
# 6. Metrics Function
# ===============================================
def calculate_metrics(y_true, y_pred, threshold=0.5, smooth=1e-6):
    y_pred_bin = (y_pred > threshold).astype(np.float32)
    pixel_acc = np.mean(y_true == y_pred_bin)
    intersection = np.sum(y_true * y_pred_bin)
    dice = (2 * intersection + smooth) / (np.sum(y_true) + np.sum(y_pred_bin) + smooth)
    union = np.sum(y_true) + np.sum(y_pred_bin) - intersection
    iou = (intersection + smooth) / (union + smooth)
    return pixel_acc, dice, iou

# ===============================================
# 7. K-Fold Cross Validation with Requested Augmentations
# ===============================================
images, masks = shuffle(images, masks, random_state=42)
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
fold_metrics = []

# ✅ Define requested augmentations
augmentations = [
    A.HorizontalFlip(p=1.0),
    A.VerticalFlip(p=1.0),
    A.GaussianBlur(blur_limit=(3,3), sigma_limit=2, p=1.0),
    A.GaussianBlur(blur_limit=(5,5), sigma_limit=4, p=1.0),
    A.Rotate(limit=270, interpolation=cv2.INTER_LINEAR, border_mode=cv2.BORDER_REFLECT_101, p=1.0),
]

for fold, (train_idx, val_idx) in enumerate(kf.split(images)):
    print(f"\n📂 Fold {fold+1}/{num_folds}")
    X_train, X_val = images[train_idx], images[val_idx]
    y_train, y_val = masks[train_idx], masks[val_idx]

    # ------------------------------------
    # Apply deterministic augmentations
    # ------------------------------------
    aug_X, aug_y = [], []
    print(f"🔄 Applying requested augmentations to training set ...")
    for img, mask in tqdm(zip(X_train, y_train), total=len(X_train)):
        # original
        aug_X.append(img)
        aug_y.append(mask)

        # each augmentation individually
        for aug in augmentations:
            augmented = aug(image=(img*255).astype(np.uint8), mask=(mask*255).astype(np.uint8))
            img_aug = augmented["image"].astype(np.float32)/255.0
            mask_aug = (augmented["mask"]>127).astype(np.float32)
            if img_aug.ndim == 2:
                img_aug = np.expand_dims(img_aug, axis=-1)
            if mask_aug.ndim == 2:
                mask_aug = np.expand_dims(mask_aug, axis=-1)
            img_aug = np.reshape(img_aug, (512,512,3))
            mask_aug = np.reshape(mask_aug, (512,512,1))
            aug_X.append(img_aug)
            aug_y.append(mask_aug)

    X_train = np.array(aug_X, dtype=np.float32)
    y_train = np.array(aug_y, dtype=np.float32)
    print(f"✅ Augmented training set: {X_train.shape}, {y_train.shape}")

    # ------------------------------------
    # Build & Train Model
    # ------------------------------------
    model = build_transunet(input_shape=(512,512,3))
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), loss=bce_dice_loss, metrics=["accuracy"])

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            f"transunet_requested_aug_fold{fold+1}.weights.h5",
            save_best_only=True,
            monitor="val_loss"
        )
    ]

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=16,
        callbacks=callbacks,
        verbose=1
    )

    # Evaluate
    preds_val = model.predict(X_val)
    pixel_acc, dice_score, iou_score = calculate_metrics(y_val, preds_val)

    print(f"✅ Fold {fold+1} Results:")
    print(f"   Pixel Accuracy: {pixel_acc:.4f}")
    print(f"   Dice Score:     {dice_score:.4f}")
    print(f"   IoU Score:      {iou_score:.4f}")

    fold_metrics.append((pixel_acc, dice_score, iou_score))

# ===============================================
# 8. Average Metrics Across Folds
# ===============================================
fold_metrics = np.array(fold_metrics)
mean_metrics = np.mean(fold_metrics, axis=0)
std_metrics = np.std(fold_metrics, axis=0)

print("\n📊 Final Cross-Validation Results:")
print(f"Pixel Accuracy: {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
print(f"Dice Score:     {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
print(f"IoU Score:      {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")
# Out:
# ✅ Dataset already extracted.
# ✅ Using dataset folder: /content/stage1_train
# 🔍 First 5 contents: ['dd54adb80393de7769b9853c0aa2ee9b240905d0e99c59d4ccd99401f327aa05', 'f0c9f135c62572f3669a75b2c735e4477dc77fac85e653426ee2b3bcfbed7aaf', '5953af5080d981b554529971903d8bee9871457a4361b51f04ba04f43793dd8f', 'f4faa3a409014db1865074c5f66a0255f71ae3faba03265da0b3b91f68e8a8f0', '0e4c2e2780de7ec4312f0efcd86b07c3738d21df30bb4643659962b4da5505a3']
# 🔍 Found 670 patient folders
# Loading patients: 100%|██████████| 670/670 [00:37<00:00, 17.92it/s]
# ✅ Images: (670, 512, 512, 3)
# ✅ Masks: (670, 512, 512, 1)
#
# 📂 Fold 1/5
# 🔄 Applying requested augmentations to training set ...
# 100%|██████████| 536/536 [00:11<00:00, 45.33it/s]
# ✅ Augmented training set: (3216, 512, 512, 3), (3216, 512, 512, 1)
# Epoch 1/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.
50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 31s 156ms/step - accuracy: 0.9950 - loss: 0.0349 - val_accuracy: 0.9797 - val_loss: 0.1743
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step
# ✅ Fold 5 Results:
#    Pixel Accuracy: 0.9797
#    Dice Score:     0.9276
#    IoU Score:      0.8650
#
# 📊 Final Cross-Validation Results:
# Pixel Accuracy: 0.9783 ± 0.0018
# Dice Score:     0.9220 ± 0.0075
# IoU Score:      0.8554 ± 0.0128

# %% [markdown]
# #Experiment 3

# %%
# ===============================================
# 0. Imports
# ===============================================
import os, zipfile
from glob import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import KFold
import tensorflow.keras.backend as K
from sklearn.utils import shuffle
import albumentations as A

# ✅ Enable mixed precision
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")

# ===============================================
# 1. Unzip Dataset + Auto Path Fix
# ===============================================
zip_path = "/content/stage1_train.zip"
extract_root = "/content/stage1_train"
os.makedirs(extract_root, exist_ok=True)

if not any(os.path.isdir(os.path.join(extract_root, d)) for d in os.listdir(extract_root)):
    print("📦 Extracting dataset...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_root)
    print("✅ Extraction completed.")
else:
    print("✅ Dataset already extracted.")

candidates = [d for d in glob(os.path.join(extract_root, "*")) if os.path.isdir(d)]
extract_path = candidates[0] if len(candidates) == 1 else extract_root
print("✅ Using dataset folder:", extract_path)
print("🔍 First 5 contents:", os.listdir(extract_path)[:5])

# ===============================================
# 2. Load Data Function
# ===============================================
def load_data(data_dir, img_size=(512, 512)):
    images, masks = [], []
    all_ids = [d for d in glob(os.path.join(data_dir, "*")) if os.path.isdir(d)]
    print(f"🔍 Found {len(all_ids)} patient folders")

    for img_id in tqdm(all_ids, desc="Loading patients"):
        img_path_list = glob(os.path.join(img_id, "images", "*.png"))
        mask_paths = glob(os.path.join(img_id, "masks", "*.png"))
        if len(img_path_list) == 0 or len(mask_paths) == 0:
            continue

        image = cv2.imread(img_path_list[0], cv2.IMREAD_COLOR)
        if image is None:
            continue
        image = cv2.resize(image, img_size)
        image = image / 255.0

        mask = np.zeros(img_size, dtype=np.uint8)
        for mp in mask_paths:
            m = cv2.imread(mp, cv2.IMREAD_GRAYSCALE)
            if m is None:
                continue
            m = cv2.resize(m, img_size)
            mask = np.maximum(mask, m)
        mask = (mask > 127).astype(np.float32)
        mask = np.expand_dims(mask, axis=-1)

        images.append(image)
        masks.append(mask)

    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.float32)

# ===============================================
# 3. Load Dataset
# ===============================================
IMG_SIZE = (512, 512)
images, masks = load_data(extract_path, img_size=IMG_SIZE)
print("✅ Images:", images.shape)
print("✅ Masks:", masks.shape)

# ===============================================
# 4. Loss Functions
# ===============================================
def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 1 - (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    return bce + dice

# ===============================================
# 5. TransUNet Model
# ===============================================
class PatchEmbedding(layers.Layer):
    def __init__(self, embed_dim=192):
        super().__init__()
        self.proj = layers.Conv2D(embed_dim, kernel_size=1, strides=1, padding="valid")
        self.flatten = layers.Reshape((-1, embed_dim))

    def call(self, x):
        x = self.proj(x)
        x = self.flatten(x)
        return x

class PositionalEncoding(layers.Layer):
    def __init__(self, num_patches, embed_dim):
        super().__init__()
        self.pos_embed = self.add_weight(
            name="pos_embed",
            shape=(1, num_patches, embed_dim),
            initializer="random_normal"
        )

    def call(self, x):
        return x + self.pos_embed

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim=192, num_heads=12, mlp_dim=768, dropout=0.1):
        super().__init__()
        self.norm1 = layers.LayerNormalization(epsilon=1e-6)
        self.attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=dropout)
        self.drop1 = layers.Dropout(dropout)
        self.norm2 = layers.LayerNormalization(epsilon=1e-6)
        self.mlp = models.Sequential([
            layers.Dense(mlp_dim, activation=tf.nn.gelu),
            layers.Dropout(dropout),
            layers.Dense(embed_dim),
            layers.Dropout(dropout),
        ])

    def call(self, x):
        attn_output = self.attn(self.norm1(x), self.norm1(x))
        x = x + self.drop1(attn_output)
        mlp_output = self.mlp(self.norm2(x))
        return x + mlp_output

def build_transformer_encoder(x, num_layers=4, embed_dim=192, num_heads=12, mlp_dim=768):
    for _ in range(num_layers):
        x = TransformerBlock(embed_dim, num_heads, mlp_dim)(x)
    return x

def build_transunet(input_shape=(512, 512, 3), num_classes=1):
    inputs = layers.Input(shape=input_shape)
    base_model = tf.keras.applications.ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
    skip1 = base_model.get_layer("conv1_relu").output
    skip2 = base_model.get_layer("conv2_block3_out").output
    skip3 = base_model.get_layer("conv3_block4_out").output
    cnn_feature = base_model.get_layer("conv4_block6_out").output

    patches = PatchEmbedding(embed_dim=192)(cnn_feature)
    num_patches = patches.shape[1]
    patches = PositionalEncoding(num_patches, 192)(patches)
    transformer_out = build_transformer_encoder(patches)

    h, w = cnn_feature.shape[1], cnn_feature.shape[2]
    x = layers.Reshape((h, w, 192))(transformer_out)

    # Decoder
    x = layers.Conv2DTranspose(512, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip3])
    x = layers.Conv2D(512, 3, padding="same", activation=tf.nn.leaky_relu)(x)
    x = layers.Conv2DTranspose(256, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip2])
    x = layers.Conv2D(256, 3, padding="same", activation=tf.nn.leaky_relu)(x)
    x = layers.Conv2DTranspose(128, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip1])
    x = layers.Conv2D(128, 3, padding="same", activation=tf.nn.leaky_relu)(x)
    x = layers.Conv2DTranspose(64, 3, strides=2, padding="same")(x)
    x = layers.Conv2D(64, 3, padding="same", activation=tf.nn.leaky_relu)(x)
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid", dtype="float32")(x)
    return models.Model(inputs, outputs, name="TransUNet")

# ===============================================
# 6. Metrics Function
# ===============================================
def calculate_metrics(y_true, y_pred, threshold=0.5, smooth=1e-6):
    y_pred_bin = (y_pred > threshold).astype(np.float32)
    pixel_acc = np.mean(y_true == y_pred_bin)
    intersection = np.sum(y_true * y_pred_bin)
    dice = (2 * intersection + smooth) / (np.sum(y_true) + np.sum(y_pred_bin) + smooth)
    union = np.sum(y_true) + np.sum(y_pred_bin) - intersection
    iou = (intersection + smooth) / (union + smooth)
    return pixel_acc, dice, iou

# ===============================================
# 7. K-Fold Cross Validation with Deterministic Augmentations
# ===============================================
images, masks = shuffle(images, masks, random_state=42)
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
fold_metrics = []

# ✅ Requested augmentations
augmentations = [
    ("blur2", A.GaussianBlur(blur_limit=(3,3), sigma_limit=(2,2), p=1.0)),
    ("noise", A.GaussNoise(var_limit=(0.01, 0.01), mean=0, p=1.0)),
    ("sharp", A.Sharpen(alpha=(1,1), lightness=(1,1), p=1.0)),
    ("rot270", A.Rotate(limit=(270,270), border_mode=cv2.BORDER_REFLECT_101, p=1.0)),
    ("rot-270", A.Rotate(limit=(-270,-270), border_mode=cv2.BORDER_REFLECT_101, p=1.0)),
    ("hflip", A.HorizontalFlip(p=1.0)),
    ("vflip", A.VerticalFlip(p=1.0))
]

for fold, (train_idx, val_idx) in enumerate(kf.split(images)):
    print(f"\n📂 Fold {fold+1}/{num_folds}")
    X_train, X_val = images[train_idx], images[val_idx]
    y_train, y_val = masks[train_idx], masks[val_idx]

    aug_X, aug_y = [], []
    print(f"🔄 Applying {len(augmentations)} deterministic augmentations ...")
    for img, mask in tqdm(zip(X_train, y_train), total=len(X_train)):
        aug_X.append(img)
        aug_y.append(mask)
        for name, aug in augmentations:
            augmented = aug(image=(img * 255).astype(np.uint8),
                            mask=(mask * 255).astype(np.uint8))
            img_aug = cv2.resize(augmented["image"], (512, 512))
            mask_aug = cv2.resize(augmented["mask"], (512, 512))
            img_aug = img_aug.astype(np.float32) / 255.0
            mask_aug = (mask_aug > 127).astype(np.float32)[..., None]
            aug_X.append(img_aug)
            aug_y.append(mask_aug)

    X_train = np.stack(aug_X, axis=0).astype(np.float32)
    y_train = np.stack(aug_y, axis=0).astype(np.float32)
    print(f"✅ Augmented training set: {X_train.shape}, {y_train.shape}")

    # Build and train
    model = build_transunet(input_shape=(512, 512, 3))
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
                  loss=bce_dice_loss,
                  metrics=["accuracy"])

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            f"transunet_custom_4_aug_fold{fold+1}.weights.h5",
            save_best_only=True,
            monitor="val_loss"
        )
    ]

    model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=16,
        callbacks=callbacks,
        verbose=1
    )

    preds_val = model.predict(X_val)
    pixel_acc, dice_score, iou_score = calculate_metrics(y_val, preds_val)

    print(f"✅ Fold {fold+1} Results:")
    print(f"   Pixel Accuracy: {pixel_acc:.4f}")
    print(f"   Dice Score:     {dice_score:.4f}")
    print(f"   IoU Score:      {iou_score:.4f}")

    fold_metrics.append((pixel_acc, dice_score, iou_score))

# ===============================================
# 8. Average Metrics Across Folds
# ===============================================
fold_metrics = np.array(fold_metrics)
mean_metrics = np.mean(fold_metrics, axis=0)
std_metrics = np.std(fold_metrics, axis=0)

print("\n📊 Final Cross-Validation Results:")
print(f"Pixel Accuracy: {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
print(f"Dice Score:     {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
print(f"IoU Score:      {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")
# Out:
# 📦 Extracting dataset...
# ✅ Extraction completed.
# ✅ Using dataset folder: /content/stage1_train
# 🔍 First 5 contents: ['70827e40a7155391984e56703c6df3392fb4a94bbd6c7008da6a6ca3244965d9', '28d33efef218392e79e385906deb88055d94b65ad217de78c07e85476f80f45a', 'c0c4a829c8d33d16a02f5dc0411597329f4b4d726ed6a22b5530cf6c8e106c4e', '2869fad54664677e81bacbf00c2256e89a7b90b69d9688c9342e2c736ff5421c', 'a022908f1b7880838dbc0411e50828e64b4f5e0263afdf04295e30bb2ff58005']
# 🔍 Found 670 patient folders
# Loading patients: 100%|██████████| 670/670 [00:29<00:00, 22.98it/s]
# ✅ Images: (670, 512, 512, 3)
# ✅ Masks: (670, 512, 512, 1)
# /tmp/ipython-input-1593086303.py:203: UserWarning: Argument(s) 'var_limit, mean' are not valid for transform GaussNoise
#   ("noise", A.GaussNoise(var_limit=(0.01, 0.01), mean=0, p=1.0)),
# 📂 Fold 1/5
# 🔄 Applying 7 deterministic augmentations ...
# 100%|██████████| 536/536 [00:21<00:00, 25.01it/s]
# ✅ Augmented training set: (4288, 512, 512, 3), (4288, 512, 512, 1)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9081 - loss: 0.5354
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 335s 272ms/step - accuracy: 0.9082 - loss: 0.5346 - val_accuracy: 0.8620 - val_loss: 3.1700
# Epoch 2/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9750 - loss: 0.1826
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 40s 150ms/step - accuracy: 0.9750 - loss: 0.1826 - val_accuracy: 0.8629 - val_loss: 2.2888
# Epoch 3/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9759 - loss: 0.1711
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 40s 150ms/step - accuracy: 0.9759 - loss: 0.1711 - val_accuracy: 0.9016 - val_loss: 1.3364
# Epoch 4/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.
# Epoch 39/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 39s 146ms/step - accuracy: 0.9930 - loss: 0.0484 - val_accuracy: 0.9754 - val_loss: 0.2255
# Epoch 40/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 39s 146ms/step - accuracy: 0.9934 - loss: 0.0463 - val_accuracy: 0.9749 - val_loss: 0.2308
# Epoch 41/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 39s 147ms/step - accuracy: 0.9936 - loss: 0.0449 - val_accuracy: 0.9755 - val_loss: 0.2275
# Epoch 42/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 39s 146ms/step - accuracy: 0.9936 - loss: 0.0453 - val_accuracy: 0.9755 - val_loss: 0.2294
# Epoch 43/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 39s 146ms/step - accuracy: 0.9938 - loss: 0.0435 - val_accuracy: 0.9755 - val_loss: 0.2305
# Epoch 44/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 39s 147ms/step - accuracy: 0.9938 - loss: 0.0439 - val_accuracy: 0.9755 - val_loss: 0.2302
# Epoch 45/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 39s 147ms/step - accuracy: 0.9940 - loss: 0.0422 - val_accuracy: 0.9753 - val_loss: 0.2405
# Epoch 46/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 39s 146ms/step - accuracy: 0.9942 - loss: 0.0408 - val_accuracy: 0.9749 - val_loss: 0.2392
# Epoch 47/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 39s 146ms/step - accuracy: 0.9940 - loss: 0.0420 - val_accuracy: 0.9751 - val_loss: 0.2443
# Epoch 48/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 39s 146ms/step - accuracy: 0.9937 - loss: 0.0432 - val_accuracy: 0.9753 - val_loss: 0.2376
# Epoch 49/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 39s 146ms/step - accuracy: 0.9943 - loss: 0.0400 - val_accuracy: 0.9754 - val_loss: 0.2398
# Epoch 50/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 39s 146ms/step - accuracy: 0.9947 - loss: 0.0378 - val_accuracy: 0.9752 - val_loss: 0.2346
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step
# ✅ Fold 5 Results:
#    Pixel Accuracy: 0.9752
#    Dice Score:     0.9091
#    IoU Score:      0.8333
#
# 📊 Final Cross-Validation Results:
# Pixel Accuracy: 0.9783 ± 0.0019
# Dice Score:     0.9222 ± 0.0069
# IoU Score:      0.8558 ± 0.0118

# %% [markdown]
# #Experiment 4

# %%
# ===============================================
# 0. Imports
# ===============================================
import os, zipfile
from glob import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import KFold
import tensorflow.keras.backend as K
from sklearn.utils import shuffle
import albumentations as A

# ✅ Enable mixed precision
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")

# ===============================================
# 1. Unzip Dataset + Auto Path Fix
# ===============================================
zip_path = "/content/stage1_train.zip"
extract_root = "/content/stage1_train"
os.makedirs(extract_root, exist_ok=True)

if not any(os.path.isdir(os.path.join(extract_root, d)) for d in os.listdir(extract_root)):
    print("📦 Extracting dataset...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_root)
    print("✅ Extraction completed.")
else:
    print("✅ Dataset already extracted.")

candidates = [d for d in glob(os.path.join(extract_root, "*")) if os.path.isdir(d)]
extract_path = candidates[0] if len(candidates) == 1 else extract_root
print("✅ Using dataset folder:", extract_path)
print("🔍 First 5 contents:", os.listdir(extract_path)[:5])

# ===============================================
# 2. Load Data Function
# ===============================================
def load_data(data_dir, img_size=(512, 512)):
    images, masks = [], []
    all_ids = [d for d in glob(os.path.join(data_dir, "*")) if os.path.isdir(d)]
    print(f"🔍 Found {len(all_ids)} patient folders")

    for img_id in tqdm(all_ids, desc="Loading patients"):
        img_path_list = glob(os.path.join(img_id, "images", "*.png"))
        mask_paths = glob(os.path.join(img_id, "masks", "*.png"))
        if len(img_path_list) == 0 or len(mask_paths) == 0:
            continue

        image = cv2.imread(img_path_list[0], cv2.IMREAD_COLOR)
        if image is None:
            continue
        image = cv2.resize(image, img_size)
        image = image / 255.0

        mask = np.zeros(img_size, dtype=np.uint8)
        for mp in mask_paths:
            m = cv2.imread(mp, cv2.IMREAD_GRAYSCALE)
            if m is None:
                continue
            m = cv2.resize(m, img_size)
            mask = np.maximum(mask, m)
        mask = (mask > 127).astype(np.float32)
        mask = np.expand_dims(mask, axis=-1)

        images.append(image)
        masks.append(mask)

    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.float32)

# ===============================================
# 3. Load Dataset
# ===============================================
IMG_SIZE = (512, 512)
images, masks = load_data(extract_path, img_size=IMG_SIZE)
print("✅ Images:", images.shape)
print("✅ Masks:", masks.shape)

# ===============================================
# 4. Loss Functions
# ===============================================
def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 1 - (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    return bce + dice

# ===============================================
# 5. TransUNet Model
# ===============================================
class PatchEmbedding(layers.Layer):
    def __init__(self, embed_dim=192):
        super().__init__()
        self.proj = layers.Conv2D(embed_dim, kernel_size=1, strides=1, padding="valid")
        self.flatten = layers.Reshape((-1, embed_dim))

    def call(self, x):
        x = self.proj(x)
        x = self.flatten(x)
        return x

class PositionalEncoding(layers.Layer):
    def __init__(self, num_patches, embed_dim):
        super().__init__()
        self.pos_embed = self.add_weight(
            name="pos_embed",
            shape=(1, num_patches, embed_dim),
            initializer="random_normal"
        )

    def call(self, x):
        return x + self.pos_embed

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim=192, num_heads=12, mlp_dim=768, dropout=0.1):
        super().__init__()
        self.norm1 = layers.LayerNormalization(epsilon=1e-6)
        self.attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=dropout)
        self.drop1 = layers.Dropout(dropout)
        self.norm2 = layers.LayerNormalization(epsilon=1e-6)
        self.mlp = models.Sequential([
            layers.Dense(mlp_dim, activation=tf.nn.gelu),
            layers.Dropout(dropout),
            layers.Dense(embed_dim),
            layers.Dropout(dropout),
        ])

    def call(self, x):
        attn_output = self.attn(self.norm1(x), self.norm1(x))
        x = x + self.drop1(attn_output)
        mlp_output = self.mlp(self.norm2(x))
        return x + mlp_output

def build_transformer_encoder(x, num_layers=4, embed_dim=192, num_heads=12, mlp_dim=768):
    for _ in range(num_layers):
        x = TransformerBlock(embed_dim, num_heads, mlp_dim)(x)
    return x

def build_transunet(input_shape=(512, 512, 3), num_classes=1):
    inputs = layers.Input(shape=input_shape)
    base_model = tf.keras.applications.ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
    skip1 = base_model.get_layer("conv1_relu").output
    skip2 = base_model.get_layer("conv2_block3_out").output
    skip3 = base_model.get_layer("conv3_block4_out").output
    cnn_feature = base_model.get_layer("conv4_block6_out").output

    patches = PatchEmbedding(embed_dim=192)(cnn_feature)
    num_patches = patches.shape[1]
    patches = PositionalEncoding(num_patches, 192)(patches)
    transformer_out = build_transformer_encoder(patches)

    h, w = cnn_feature.shape[1], cnn_feature.shape[2]
    x = layers.Reshape((h, w, 192))(transformer_out)

    # Decoder
    x = layers.Conv2DTranspose(512, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip3])
    x = layers.Conv2D(512, 3, padding="same", activation=tf.nn.leaky_relu)(x)
    x = layers.Conv2DTranspose(256, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip2])
    x = layers.Conv2D(256, 3, padding="same", activation=tf.nn.leaky_relu)(x)
    x = layers.Conv2DTranspose(128, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip1])
    x = layers.Conv2D(128, 3, padding="same", activation=tf.nn.leaky_relu)(x)
    x = layers.Conv2DTranspose(64, 3, strides=2, padding="same")(x)
    x = layers.Conv2D(64, 3, padding="same", activation=tf.nn.leaky_relu)(x)
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid", dtype="float32")(x)
    return models.Model(inputs, outputs, name="TransUNet")

# ===============================================
# 6. Metrics Function
# ===============================================
def calculate_metrics(y_true, y_pred, threshold=0.5, smooth=1e-6):
    y_pred_bin = (y_pred > threshold).astype(np.float32)
    pixel_acc = np.mean(y_true == y_pred_bin)
    intersection = np.sum(y_true * y_pred_bin)
    dice = (2 * intersection + smooth) / (np.sum(y_true) + np.sum(y_pred_bin) + smooth)
    union = np.sum(y_true) + np.sum(y_pred_bin) - intersection
    iou = (intersection + smooth) / (union + smooth)
    return pixel_acc, dice, iou

# ===============================================
# 7. K-Fold Cross Validation with Deterministic Augmentations
# ===============================================
images, masks = shuffle(images, masks, random_state=42)
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
fold_metrics = []

# ✅ Requested augmentations
augmentations = [
    ("blur2", A.GaussianBlur(blur_limit=(3,3), sigma_limit=(2,2), p=1.0)),
    ("blur4", A.GaussianBlur(blur_limit=(3,3), sigma_limit=(4,4), p=1.0)),
    ("noise", A.GaussNoise(var_limit=(0.01, 0.01), mean=0, p=1.0)),
    ("sharp", A.Sharpen(alpha=(1,1), lightness=(1,1), p=1.0)),
    ("rot270", A.Rotate(limit=(270,270), border_mode=cv2.BORDER_REFLECT_101, p=1.0)),
    ("rot-270", A.Rotate(limit=(-270,-270), border_mode=cv2.BORDER_REFLECT_101, p=1.0)),
    ("hflip", A.HorizontalFlip(p=1.0)),
    ("vflip", A.VerticalFlip(p=1.0))
]

for fold, (train_idx, val_idx) in enumerate(kf.split(images)):
    print(f"\n📂 Fold {fold+1}/{num_folds}")
    X_train, X_val = images[train_idx], images[val_idx]
    y_train, y_val = masks[train_idx], masks[val_idx]

    aug_X, aug_y = [], []
    print(f"🔄 Applying {len(augmentations)} deterministic augmentations ...")
    for img, mask in tqdm(zip(X_train, y_train), total=len(X_train)):
        aug_X.append(img)
        aug_y.append(mask)
        for name, aug in augmentations:
            augmented = aug(image=(img * 255).astype(np.uint8),
                            mask=(mask * 255).astype(np.uint8))
            img_aug = cv2.resize(augmented["image"], (512, 512))
            mask_aug = cv2.resize(augmented["mask"], (512, 512))
            img_aug = img_aug.astype(np.float32) / 255.0
            mask_aug = (mask_aug > 127).astype(np.float32)[..., None]
            aug_X.append(img_aug)
            aug_y.append(mask_aug)

    X_train = np.stack(aug_X, axis=0).astype(np.float32)
    y_train = np.stack(aug_y, axis=0).astype(np.float32)
    print(f"✅ Augmented training set: {X_train.shape}, {y_train.shape}")

    # Build and train
    model = build_transunet(input_shape=(512, 512, 3))
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
                  loss=bce_dice_loss,
                  metrics=["accuracy"])

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            f"transunet_custom_3_aug_fold{fold+1}.weights.h5",
            save_best_only=True,
            monitor="val_loss"
        )
    ]

    model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=16,
        callbacks=callbacks,
        verbose=1
    )

    preds_val = model.predict(X_val)
    pixel_acc, dice_score, iou_score = calculate_metrics(y_val, preds_val)

    print(f"✅ Fold {fold+1} Results:")
    print(f"   Pixel Accuracy: {pixel_acc:.4f}")
    print(f"   Dice Score:     {dice_score:.4f}")
    print(f"   IoU Score:      {iou_score:.4f}")

    fold_metrics.append((pixel_acc, dice_score, iou_score))

# ===============================================
# 8. Average Metrics Across Folds
# ===============================================
fold_metrics = np.array(fold_metrics)
mean_metrics = np.mean(fold_metrics, axis=0)
std_metrics = np.std(fold_metrics, axis=0)

print("\n📊 Final Cross-Validation Results:")
print(f"Pixel Accuracy: {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
print(f"Dice Score:     {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
print(f"IoU Score:      {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")
# Out:
# 📦 Extracting dataset...
# ✅ Extraction completed.
# ✅ Using dataset folder: /content/stage1_train
# 🔍 First 5 contents: ['4590d7d47f521df62f3bcb0bf74d1bca861d94ade614d8afc912d1009d607b94', 'cf26c41245febfe67c2a1682cc4ee8752ee40ae3e49610314f45923b8bf5b08a', '74a7785530687a11ecd073e772f90912d9967d02407a192bfab282c35f55ab94', '3a22fe593d9606d4f137461dd6802fd3918f9fbf36f4a65292be69670365e2ca', '8b77284d6f37ab3fc826139ebadaec3b9d81c552fe525c3547bbbd6c65ac0d83']
